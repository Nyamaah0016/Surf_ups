# %% [markdown]
# # Overview

# %% [markdown]
# ### Purpose

# %% [markdown]
# The main objective of this analysis is to enable a stakeholder with appropriate statistical summary report to explore whether the idea of setting up the a surf shop in the city. This report will majorily focus on Minimum, Maximum, Mean. In addition usage of SQLAlchemy to connect with SQLite.

# %% [markdown]
# - Source: hawaii.sqlite
# - SurfsUp_Challenge.ipynb, climate_analysis.ipynb
# - Python SQL toolkit (SQLAlchemy), Object Relational Mapper, Pandas, Matplotlib, Numpy
# - Jupyter Notebook

# %% [markdown]
# # Results

# %% [markdown]
# - The mean temperature of June is higher than December
#   - The mean june temperature is 75 degree
#   - The mean december temperature is 71 degree
#   - The temperature ranges between 64 to 85 degrees for June
#   - The temperature ranges between 56 to 83 degrees for December
# - In the below given plots one can notice that June is left skewed but December is symmetrical
# - Temperature increases and precipitation decreases more in June than in December

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### June Temperature Graph

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### December Temperature Graph

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Precipitation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Summary

# %% [markdown]
# The result shows that investing in the business of Surf is good in Hawaii which makes it an ideal location for the same. The temperature seems same throughout the year. The rainfall is also low in Hawaii. The temperature data is not strongly skewed for any of the month (neither June nor December). Hence the data gives a green signal to start the business in the location.
